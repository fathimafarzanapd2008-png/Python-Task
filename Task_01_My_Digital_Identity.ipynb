# %%
from posixpath import defpath
from typing_extensions import NamedTuple
# Task 1 — My Digital Identity

# Fill in your actual details inside the quotes
name = "Fathima farzana"
reg_no = "JSOFT26122"
dept = "BCA Full Stack AI Development"
semester = "1st Semester"
skills = "Python, HTML, C++, Problem Solving"
hobbies = "Dancing, Music, Drawing"
dream_company = "Google"
github = "https://github.com/fathimafarzanapd2008-png"
linkedin = "www.linkedin.com/in/fathima-farzana-p-d-2ab003427"
career_goal = "To become a Software Development Engineer"

# Displaying the Digital Identity Profile Card
print("==================================================")
print("            MY DIGITAL IDENTITY CARD              ")
print("==================================================")
print(f" Name           : {name}")
print(f" Register No.   : {reg_no}")
print(f" Department     : {defpath}")
print(f" Semester       : {semester}")
print(f" Skills         : {skills}")
print(f" Hobbies        : {hobbies}")
print(f" Dream Company  : {dream_company}")
print(f" GitHub         : {github}")
print(f" LinkedIn       : {linkedin}")
print(f" Career Goal    : {career_goal}")
print("==================================================")
# Out:
# ...
#             MY DIGITAL IDENTITY CARD
# ...
#  Name           : Fathima farzana
#  Register No.   : JSOFT26122
#  Department     : /bin:/usr/bin
#  Semester       : 1st Semester
#  Skills         : Python, HTML, C++, Problem Solving
#  Hobbies        : Dancing, Music, Drawing
#  Dream Company  : Google
#  GitHub         : https://github.com/fathimafarzanapd2008-png
#  LinkedIn       : www.linkedin.com/in/fathima-farzana-p-d-2ab003427
#  Career Goal    : To become a Software Development Engineer
# ...
