# %% [markdown]
# <a href="https://colab.research.google.com/github/fathimafarzanapd2008-png/Python-Task/blob/main/Task_02_student_profile_Manager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 2 - Student Profile Manager
name = input("Name: ")
age = int(input("Age: "))
department = input("Department: ")
cgpa = float(input("CGPA: "))
blood_group = input("Blood Group: ")
email = input("Email: ")
phone = input("Phone: ")

print("\n" + "=" * 40)
print("         STUDENT PROFILE")
print("=" * 40)
print(f"Name        : {name}")
print(f"Age         : {age}")
print(f"Department  : {department}")
print(f"CGPA        : {cgpa}")
print(f"Blood Group : {blood_group}")
print(f"Email       : {email}")
print(f"Phone       : {phone}")
print("=" * 40)
# Out:
# Name: Fathima Farzana P.D
# Age: 18
# Department: BCA Full Stack AI Development
# CGPA: 9.0
# Blood Group: o+
# Email: user@gmail.com
# Phone: 9876543210
#
# ...
#          STUDENT PROFILE
# ...
# Name        : Fathima Farzana P.D
# Age         : 18
# Department  : BCA Full Stack AI Development
# CGPA        : 9.0
# Blood Group : o+
# Email       : user@gmail.com
# Phone       : 9876543210
# ...
