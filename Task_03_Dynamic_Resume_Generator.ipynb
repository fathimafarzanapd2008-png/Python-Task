# %% [markdown]
# <a href="https://colab.research.google.com/github/fathimafarzanapd2008-png/Python-Task/blob/main/Task_03_Dynamic_Resume_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task 3 - Resume Generator
name = input("Full Name: ")
education = input("Education: ")
skills = input("Skills (comma separated): ")
projects = input("Projects (comma separated): ")
languages = input("Languages known: ")

print("\n" + "=" * 45)
print(f"{name.upper():^45}")
print("=" * 45)
print("\nEDUCATION")
print("-" * 45)
print(education)
print("\nSKILLS")
print("-" * 45)
for s in skills.split(","):
    print(f"  • {s.strip()}")
print("\nPROJECTS")
print("-" * 45)
for p in projects.split(","):
    print(f"  • {p.strip()}")
print("\nLANGUAGES")
print("-" * 45)
print(languages)
print("=" * 45)
# Out:
# Full Name: Fathima Farzana P.D
# Education: BCA Full Stack AI Development
# Skills (comma separated): python, HTML, C++, Problem Solving
# Projects (comma separated): Student Profile Manager, Resume Generator
# Languages known: English, Malayalam, Hindi
#
# ...
#              FATHIMA FARZANA P.D
# ...
#
# EDUCATION
# ---------------------------------------------
# BCA Full Stack AI Development
#
# SKILLS
# ---------------------------------------------
#   • python
#   • HTML
#   • C++
#   • Problem Solving
#
# PROJECTS
# ---------------------------------------------
#   • Student Profile Manager
#   • Resume Generator
#
# LANGUAGES
# ---------------------------------------------
# English, Malayalam, Hindi
# ...
